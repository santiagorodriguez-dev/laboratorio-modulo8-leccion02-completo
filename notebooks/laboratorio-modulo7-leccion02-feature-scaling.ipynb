# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# # Laboratorio de Feature Scaling
#
# Continuando con nuestro proyecto en AutoRenew, la empresa de coches de segunda mano, en este laboratorio abordarás una fase crucial del preprocesamiento de datos: el **Feature Scaling**. Este paso es esencial para asegurar que todas las características (variables) de los coches se encuentren en la misma escala antes de entrenar los modelos de Machine Learning. Esto evitará que algunas características dominen sobre otras debido a sus rangos de valores diferentes, mejorando así la precisión del modelo predictivo que estás desarrollando.
#
# Tu tarea en este laboratorio es aplicar técnicas de Feature Scaling a las características del conjunto de datos que consideres relevantes. Este paso es fundamental para preparar los datos de manera adecuada para el entrenamiento de modelos de Machine Learning, lo que haremos en los próximos ejercicios.
#
# **Columnas del conjunto de datos que podrías escalar:**
#
# - **price**: Precio del coche.
#
# - **powerCV**: Potencia del coche en caballos de vapor (CV).
#
# - **kilometer**: Kilometraje total del coche.
#
# - **yearOfRegistration**: Año de registro del coche (aunque es una característica temporal, en algunos casos puede necesitar escalado dependiendo del enfoque del modelo).
#
# - **monthOfRegistration**: Mes de registro del coche.
#
# **Instrucciones:**
#
# 1. **Identificación de las características a escalar:** Revisa el conjunto de datos y selecciona las columnas que deberían ser escaladas. Estas generalmente incluyen características numéricas continuas como el precio, la potencia y el kilometraje.
#
# 2. **Aplicación de técnicas de Feature Scaling**
#
#
# 3. **Comparación de resultados:** Después de aplicar el escalado, observa cómo han cambiado las distribuciones de las características. Evalúa cuál de las técnicas de escalado es más apropiada para este conjunto de datos y justifica tu elección.
#
# **Nota:** Este laboratorio se construye sobre el análisis exploratorio y la gestión de nulos que realizaste anteriormente. Asegúrate de mantener una buena documentación de tus procesos, ya que utilizaremos estos datos escalados en las próximas etapas de modelado de Machine Learning.

# %%
# Para gestionar el feature scaling
# -----------------------------------------------------------------------
from sklearn.preprocessing import MinMaxScaler, Normalizer, StandardScaler, RobustScaler

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import sys
sys.path.append("../")
from src import soporte_preprocesamiento as sc
from src import soporte_nulos as sn
from src import soporte as sp

# %%
df = pd.read_csv("../data/autorenew_clean.csv", index_col=0)

# %%
df.head()
# Out:
#                              name   seller offerType abtest vehicleType  \
# 0                      Golf_3_1.6  private     offer   test     Unknown
# 1            A5_Sportback_2.7_Tdi  private     offer   test       coupe
# 2  Jeep_Grand_Cherokee_"Overland"  private     offer   test         suv
# 3              GOLF_4_1_4__3TÜRER  private     offer   test   small car
# 4  Skoda_Fabia_1.4_TDI_PD_Classic  private     offer   test   small car
#
#      gearbox    model fuelType       brand notRepairedDamage  \
# 0   manually     golf   petrol  volkswagen           Unknown
# 1   manually  Unknown   diesel        audi               yes
# 2  automatic    grand   diesel        jeep           Unknown
# 3   manually     golf   petrol  volkswagen                no
# 4   manually    fabia   diesel       skoda                no
#
#            dateCreated             lastSeen  price_knn  \
# 0  2016-03-24 00:00:00  2016-04-07 03:16:57      480.0
# 1  2016-03-24 00:00:00  2016-04-07 01:46:50    18300.0
# 2  2016-03-14 00:00:00  2016-04-05 12:47:46     9800.0
# 3  2016-03-17 00:00:00  2016-03-17 17:40:17     1500.0
# 4  2016-03-31 00:00:00  2016-04-06 10:17:21     3600.0
#
#    yearOfRegistration_knn  powerCV_knn  kilometer_knn  \
# 0                  1993.0          0.0       150000.0
# 1                  2011.0        187.0       125000.0
# 2                  2004.0        161.0       125000.0
# 3                  2001.0         74.0       150000.0
# 4                  2008.0         68.0        90000.0
#
#    monthOfRegistration_knn  nrOfPictures_knn  postalCode_knn
# 0                      0.0               0.0         70435.0
# 1                      5.0               0.0         66954.0
# 2                      8.0               0.0         90480.0
# 3                      6.0               0.0         91074.0
# 4                      7.0               0.0         60437.0

# %%
sc.exploracion_datos(df)
# Out:
# El número de filas es 371499 y el número de columnas es 19
#
# ----------
#
# En este conjunto de datos tenemos 0 valores duplicados
#
# ----------
#
# Los columnas con valores nulos y sus porcentajes son:
# Series([], dtype: float64)
# ----------
#
# Las principales estadísticas de las variables númericas son:
#                             count           mean           std     min  \
# price_knn                371499.0   17295.957876  3.588094e+06     0.0
# yearOfRegistration_knn   371499.0    2004.578311  9.287018e+01  1000.0
# powerCV_knn              371499.0     113.967653  1.895232e+02     0.0
# kilometer_knn            371499.0  125619.221048  4.011236e+04  5000.0
# monthOfRegistration_knn  371499.0       5.734414  3.712406e+00     0.0
# nrOfPictures_knn         371499.0       0.000000  0.000000e+00     0.0
# postalCode_knn           371499.0   50820.195696  2.579932e+04  1067.0
#
#                               25%       50%       75%           max
# price_knn                  1150.0    2950.0    7200.0  2.147484e+09
# yearOfRegistration_knn     1999.0    2003.0    2008.0  9.999000e+03
# powerCV_knn                  69.0     104.0     148.0  1.972600e+04
# kilometer_knn            125000.0  150000.0  150000.0  1.500000e+05
# monthOfRegistration_knn       3.0       6.0       9.0  1.200000e+01
# nrOfPictures_knn              0.0       0.0       0.0  0.000000e+00
# postalCode_knn            30459.0   49610.0   71546.0  9.999800e+04
# ----------
#
# Las principales estadísticas de las variables categóricas son:
#                     count  unique                  top    freq
# name               371499  233531          Ford_Fiesta     657
# seller             371499       2              private  371496
# offerType          371499       2                offer  371487
# abtest             371499       2                 test  192575
# vehicleType        371499       8              Unknown  133757
# gearbox            371499       3             manually  274193
# model              371499     252                 golf   30070
# fuelType           371499       8               petrol  223841
# brand              371499      40           volkswagen   79638
# notRepairedDamage  371499       3                   no  263159
# dateCreated        371499     114  2016-04-03 00:00:00   14445
# lastSeen           371499  182806  2016-04-06 13:45:54      17
# ----------
#
# Las características principales del dataframe son:
# <class 'pandas.core.frame.DataFrame'>
# Index: 371499 entries, 0 to 371498
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   name                     371499 non-null  object
#  1   seller                   371499 non-null  object
#  2   offerType                371499 non-null  object
#  3   abtest                   371499 non-null  object
#  4   vehicleType              371499 non-null  object
#  5   gearbox                  371499 non-null  object
#  6   model                    371499 non-null  object
#  7   fuelType                 371499 non-null  object
#  8   brand                    371499 non-null  object
#  9   notRepairedDamage        371499 non-null  object
#  10  dateCreated              371499 non-null  object
#  11  lastSeen                 371499 non-null  object
#  12  price_knn                371499 non-null  float64
#  13  yearOfRegistration_knn   371499 non-null  float64
#  14  powerCV_knn              371499 non-null  float64
#  15  kilometer_knn            371499 non-null  float64
#  16  monthOfRegistration_knn  371499 non-null  float64
#  17  nrOfPictures_knn         371499 non-null  float64
#  18  postalCode_knn           371499 non-null  float64
# dtypes: float64(7), object(12)
# memory usage: 56.7+ MB
# None

# %% [markdown]
# **Decidimos que esta es categorica y la convertimos a Object y no la tratamos como numerica.**
#
# - **monthOfRegistration**: Mes de registro del coche.

# %%
df['monthOfRegistration_knn'] = df['monthOfRegistration_knn'].astype("O")

# %% [markdown]
# - **powerCV**: Potencia del coche en caballos de vapor (CV).
#
# - **kilometer**: Kilometraje total del coche.
#
# - **yearOfRegistration**: Año de registro del coche (aunque es una característica temporal, en algunos casos puede necesitar escalado dependiendo del enfoque del modelo).
#
# Nos quedamos con estas 3 columnas para la estandarizacion de datos

# %%
df = sp.analisis_numericos(df)

# %%
df.describe().T
# Out:
#                                    count          mean           std  \
# price_knn                       371499.0  1.729596e+04  3.588094e+06
# yearOfRegistration_knn          371499.0  2.004578e+03  9.287018e+01
# powerCV_knn                     371499.0  1.139677e+02  1.895232e+02
# kilometer_knn                   371499.0  1.256192e+05  4.011236e+04
# nrOfPictures_knn                371499.0  0.000000e+00  0.000000e+00
# postalCode_knn                  371499.0  5.082020e+04  2.579932e+04
# powerCV_robust                  371499.0  1.261728e-01  2.399028e+00
# kilometer_Ratesrobust           371499.0 -9.752312e-01  1.604495e+00
# yearOfRegistration_Ratesrobust  371499.0  1.753679e-01  1.031891e+01
# powerCV_min_max                 371499.0  5.777535e-03  9.607788e-03
# kilometer_min_max               371499.0  8.318567e-01  2.766370e-01
# yearOfRegistration_min_max      371499.0  1.116322e-01  1.032006e-02
# powerCV_norm                    371499.0  1.429052e-03  5.920597e-03
# kilometer_norm                  371499.0  9.981963e-01  1.100309e-02
# yearOfRegistration_norm         371499.0  2.665068e-02  5.230442e-02
# powerCV_estandar                371499.0 -2.295164e-18  1.000001e+00
# kilometer_estandar              371499.0 -7.271846e-17  1.000001e+00
# yearOfRegistration_estandar     371499.0 -3.755463e-16  1.000001e+00
#
#                                         min            25%            50%  \
# price_knn                          0.000000    1150.000000    2950.000000
# yearOfRegistration_knn          1000.000000    1999.000000    2003.000000
# powerCV_knn                        0.000000      69.000000     104.000000
# kilometer_knn                   5000.000000  125000.000000  150000.000000
# nrOfPictures_knn                   0.000000       0.000000       0.000000
# postalCode_knn                  1067.000000   30459.000000   49610.000000
# powerCV_robust                    -1.316456      -0.443038       0.000000
# kilometer_Ratesrobust             -5.800000      -1.000000       0.000000
# yearOfRegistration_Ratesrobust  -111.444444      -0.444444       0.000000
# powerCV_min_max                    0.000000       0.003498       0.005272
# kilometer_min_max                  0.000000       0.827586       1.000000
# yearOfRegistration_min_max         0.000000       0.111012       0.111457
# powerCV_norm                       0.000000       0.000493       0.000820
# kilometer_norm                     0.277839       0.999863       0.999910
# yearOfRegistration_norm            0.006666       0.013332       0.013372
# powerCV_estandar                  -0.601340      -0.237268      -0.052593
# kilometer_estandar                -3.007038      -0.015437       0.607813
# yearOfRegistration_estandar      -10.817032      -0.060066      -0.016995
#
#                                           75%           max
# price_knn                         7200.000000  2.147484e+09
# yearOfRegistration_knn            2008.000000  9.999000e+03
# powerCV_knn                        148.000000  1.972600e+04
# kilometer_knn                   150000.000000  1.500000e+05
# nrOfPictures_knn                     0.000000  0.000000e+00
# postalCode_knn                   71546.000000  9.999800e+04
# powerCV_robust                       0.556962  2.483797e+02
# kilometer_Ratesrobust                0.000000  0.000000e+00
# yearOfRegistration_Ratesrobust       0.555556  8.884444e+02
# powerCV_min_max                      0.007503  1.000000e+00
# kilometer_min_max                    1.000000  1.000000e+00
# yearOfRegistration_min_max           0.112012  1.000000e+00
# powerCV_norm                         0.001213  9.542097e-01
# kilometer_norm                       0.999911  9.999562e-01
# yearOfRegistration_norm              0.016142  7.071068e-01
# powerCV_estandar                     0.179568  1.034810e+02
# kilometer_estandar                   0.607813  6.078129e-01
# yearOfRegistration_estandar          0.036844  8.608180e+01

# %%
data=["powerCV_robust","powerCV_min_max","powerCV_norm","powerCV_estandar","powerCV_knn",
      "kilometer_Ratesrobust","kilometer_min_max","kilometer_norm","kilometer_estandar","kilometer_knn",
      "yearOfRegistration_Ratesrobust","yearOfRegistration_min_max","yearOfRegistration_norm","yearOfRegistration_estandar","yearOfRegistration_knn"]

sp.visualizar_tablas(df,data)

# %% [markdown]
# 3. **Comparación de resultados:** Después de aplicar el escalado, observa cómo han cambiado las distribuciones de las características. Evalúa cuál de las técnicas de escalado es más apropiada para este conjunto de datos y justifica tu elección.

# %% [markdown]
# **Observando los datos nos quedamos con StandardScaler, debido a que el rango de los datos es menor y para posteriores analisis, el peso de los datos estara mas equilibrado. Ademas en el analisis previo vimos que los outlayers parecen valores no validos que trataremos despues y lo que nos interesa es tener un rango menor de los datos**

# %%
df.to_csv("../data/autorenew_clean_estandar.csv")

# %%
df.shape[0]
# Out:
# 371499
